# %%
from numpy import *
import pylab as p
# Definition of parameters
mu= 3.0
def dX_dt(X, t=0):
    xpri=X[1]
    ypri=mu*(1-X[0]**2)*X[1]-X[0]
    return array([xpri, ypri ])

# %%
from scipy.integrate import odeint 
from scipy import array
import matplotlib.pyplot as plt

stoptime = 5.0
numpoints = 5000

#Tiempo
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

#Condiciones iniciales
xi = -9.0
vi = -3.0

#Resolver ecuaciones
x, y = odeint(dX_dt,(xi,vi),t).T

with open('parte1.dat', 'w') as archivo:
    for t1, x1,y1 in zip(t, x, y):
        print (t1, x1,y1 ,file=archivo)

# %%
from scipy.integrate import odeint 
from scipy import array
import matplotlib.pyplot as plt

stoptime = 6.0
numpoints = 5000

#Tiempo
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

#Condiciones iniciales
x1 = -1.0
v1 = -4.0

#Resolver ecuaciones
x, y = odeint(dX_dt,(x1,v1),t).T

with open('parte2.dat', 'w') as archivo:
    for t2, x2,y2 in zip(t, x, y):
        print (t2, x2,y2 ,file=archivo)

# %%
from scipy.integrate import odeint 
from scipy import array
import matplotlib.pyplot as plt

stoptime = 6.0
numpoints = 5000

#Tiempo
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

#Condiciones iniciales
x2 = 1.0
v2 = 2.0

#Resolver ecuaciones
x, y = odeint(dX_dt,(x2,v2),t).T

with open('parte3.dat', 'w') as archivo:
    for t3, x3,y3 in zip(t, x, y):
        print (t3, x3,y3 ,file=archivo)

# %%
from scipy.integrate import odeint 
from scipy import array
import matplotlib.pyplot as plt

stoptime = 6.0
numpoints = 5000

#Tiempo
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

#Condiciones iniciales
x3= -2.0
v3 = 4.0

#Resolver ecuaciones
x, y = odeint(dX_dt,(x3,v3),t).T

with open('parte4.dat', 'w') as archivo:
    for t4, x4,y4 in zip(t, x, y):
        print (t4,x4,y4,file=archivo)

# %%
from scipy.integrate import odeint 
from scipy import array
import matplotlib.pyplot as plt

stoptime = 6.0
numpoints = 5000

#Tiempo
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

#Condiciones iniciales
x4 = 2
v4 = 0.0

#Resolver ecuaciones
x, y = odeint(dX_dt,(x4,v4),t).T

with open('parte5.dat', 'w') as archivo:
    for t5, x5,y5 in zip(t, x, y):
        print (t5, x5,y5 ,file=archivo)

# %%
from pylab import figure, plot, xlabel, xlim, ylim, ylabel, grid, hold, legend, title, savefig
# %matplotlib inline

f1= figure()

#Var. 1
t, x, y = loadtxt('parte1.dat', unpack=True)
plot(x, y, 'b-')

grid()
xlim(-10,10)
ylim(-10, 10)
xlabel('x')
ylabel('y')
title('Phase portrait of the unforced Van der Pol oscillator')
f1.savefig('extra1.1.png')

# %%
from pylab import figure, plot, xlabel, xlim, ylim, ylabel, grid, hold, legend, title, savefig
# %matplotlib inline

f1= figure()

#Var. 2
t, x, y = loadtxt('parte2.dat', unpack=True)
plot(x, y, 'tab:cyan')

grid()
xlim(-10,10)
ylim(-10, 10)
xlabel('x')
ylabel('y')
title('Phase portrait of the unforced Van der Pol oscillator')
f1.savefig('extra2.png')

# %%
from pylab import figure, plot, xlabel, xlim, ylim, ylabel, grid, hold, legend, title, savefig
# %matplotlib inline

f1= figure()

#Var. 3
t, x, y = loadtxt('parte3.dat', unpack=True)
plot(x, y, 'm')

grid()
xlim(-10,10)
ylim(-10, 10)
xlabel('x')
ylabel('y')
title('Phase portrait of the unforced Van der Pol oscillator')
f1.savefig('extra3.png')

# %%
from pylab import figure, plot, xlabel, xlim, ylim, ylabel, grid, hold, legend, title, savefig
# %matplotlib inline

f1= figure()

#Var. 4
t, x, y = loadtxt('parte4.dat', unpack=True)
plot(x, y, 'k')

grid()
xlim(-10,10)
ylim(-10, 10)
xlabel('x')
ylabel('y')
title('Phase portrait of the unforced Van der Pol oscillator')
f1.savefig('extra4.png')

# %%
from pylab import figure, plot, xlabel, xlim, ylim, ylabel, grid, hold, legend, title, savefig
# %matplotlib inline

f1= figure()

#Var. 5
t, x, y = loadtxt('parte5.dat', unpack=True)
plot(x, y, 'tab:red')

grid()
xlim(-10,10)
ylim(-10, 10)
xlabel('x')
ylabel('y')
title('Phase portrait of the unforced Van der Pol oscillator')
f1.savefig('extra5.png')
